# %% [raw]
# ---
# title: "My document"
# execute:
#   enabled: true
# format:
#   pdf:
#     toc: true
#     number-sections: true
#     colorlinks: true
# ---

# %%
import numpy as np
y = 0.5
x = np.arctan(1) * 4
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# The value of $\pi$ up to 4 sifnificant digits is `{python} f"{x:.4g}"`
